# %% [markdown]
# <a href="https://colab.research.google.com/github/dlora2024/Prob-Stat/blob/main/Lab_2_Hist_Normal_Dist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
numbers= np.array([1,2,2,3,3,3,4,4,4,4])#Numbers for Hist

# %%
plt.hist(numbers,100);#Plot Hist

# %% [markdown]
# # PRNG

# %%
x = 0.12345#Value of x

# %%
x = x*3#Times x by 3

# %%
x % 1#Remanider of Int
# Out:
# 0.37035

# %%
current_point = 0.12345# seed value
points_to_save = np.zeros(50000,)  # initialize an array of zeros

for i in range(points_to_save .shape[0]):
    current_point = 3*current_point % 1 # update x and store the value in X
    points_to_save[i] = current_point

plt.plot(points_to_save, '.')# plot the values in X

# %%
plt.hist(points_to_save);

# %%
def coin():#Define Coin
    return 2*(np.random.random() > 0.5) - 1#Flip coin if bigger then 0.5 then heads/1

# %%
coin()#Display value of coin
# Out:
# 1

# %%
x = 0#Set value for x
x + coin()#Add random value to x
# Out:
# 1

# %%
x = 0#Set value for x

for i in range(3):#Loop 3 times
    x = x + coin()#x is equal to X plus random number

# %%
x#print x
# Out:
# 1

# %%
x = 0#Set X

for i in range(100):#Loop 100 times
    x = x + coin()#x is equal to X plus random number

# %%
x
# Out:
# 18

# %%
M = 10000#Set M
N = 100#Set N

X = np.zeros(M,)#Set x as array with size of M

for j in range(M):#Loop M times

    x = 0#Set X

    for i in range(N):#Loop N times
        x = x + coin()##x is equal to X plus random number

    X[j] = x#Cummulative sum of coin flip and stored in X

# %%
plt.hist(X);#Plot X

# %% [markdown]
# # Normal Distribution

# %%
# Define the parameters for the normal distribution
mean = 0  # Mean (mu) of the distribution
std_dev = 0.1  # Standard deviation (sigma) of the distribution

# Generate 1000 data points following a normal distribution with the specified mean and standard deviation
sample_size = 10000
data_points = np.random.normal(mean, std_dev, sample_size)

# Plot the histogram of the data points
bins_number = 30  # Number of bins for the histogram
hist_count, x, ignored = plt.hist(data_points, bins_number, density=True)

# %%
x = np.linspace(-15,15,1000)#1,000 values bewteen -15 to 15

y = np.exp(-x**2)#Used to calcualte the exponential of eah x value raised to the 2 power

# %%
plt.plot(x,y)#Plot X and Y

# %%
y2 = np.sin(10*x)#Sin of 10 time X

# %%
plt.plot(x,y2)#Plot x and y

# %%
plt.plot(x,y*y2)#Y sqaured

# %%
y3 =  np.exp(- (x - 0) ** 2 )#Expno. of X raised to the power of 2
plt.plot(x, y3, linewidth=10, color='r')#Thickness of line and color

# %%
# Define the parameters for the normal distribution
mean = 0  # Mean (mu) of the distribution
std_dev = 0.1  # Standard deviation (sigma) of the distribution

# Generate 1000 data points following a normal distribution with the specified mean and standard deviation
sample_size = 10000
data_points = np.random.normal(mean, std_dev, sample_size)

# Plot the histogram of the data points
bins_number = 30  # Number of bins for the histogram
hist_count, x, ignored = plt.hist(data_points, bins_number, density=True)

# Plot the probability density function of the normal distribution
normal_dist_curve = 1 / (std_dev * np.sqrt(2 * np.pi)) * np.exp(- (x - mean) ** 2 / (2 * std_dev ** 2))
plt.plot(x, normal_dist_curve, linewidth=2, color='r')

# Set the title and labels for the plot
plt.title('Normal Distribution Visualization')
plt.xlabel('Value')
plt.ylabel('Probability Density')

# Display the plot
plt.show()

# %%
x = np.array([1,2,3,4])#Array

# %%
np.sum(x)#Adds up all the numbers in the array
# Out:
# 10

# %%
x.shape[0]#Number of columns
# Out:
# 4

# %%
np.sum(x)/x.shape[0]#Sum of X divided by numbers of colums
# Out:
# 2.5

# %%
def mean(x):#Define means as x
    return np.sum(x)/x.shape[0]#Set X

# %%
mean(x)#print X
# Out:
# 2.5

# %%
x#print x
# Out:
# array([1, 2, 3, 4])

# %%
x - mean(x)#Array of X minus the mean
# Out:
# array([-1.5, -0.5,  0.5,  1.5])

# %%
(x - mean(x))**2#Array of X minus the mean to the second power
# Out:
# array([2.25, 0.25, 0.25, 2.25])

# %%
 def var(x):#Var calculates the variance of the array x
    return mean((x - mean(x))**2)#Array of X minus the mean to the second power|

# %%
def std(x):#Standard deviation of x
    return np.sqrt(var(x))#sqet of x

# %%
mean(x)#Mean Value
# Out:
# 2.5

# %%
var(x)#Variance Value
# Out:
# 1.25

# %%
std(x)#Standard Deviation Value
# Out:
# 1.118033988749895

# %% [markdown]
# ### Uniform Random Numbers

# %%
X = np.random.random(500000,)#Random Num 500000 times

# %%
X#Print X
# Out:
# array([0.74825448, 0.80104096, 0.87174668, ..., 0.12294742, 0.38511592,
#        0.08180445])

# %%
plt.hist(X,100);#Plot X, 100 is the number of bins

# %%
np.random.random()#Print Random
# Out:
# 0.47637578107409007

# %%
r = np.random.random()#Set r as randomm number

# %%
r#Print R
# Out:
# 0.931295235003926

# %%
r = np.random.randint(1,10)#Rand Num from 10 to 10

# %%
r#Print R
# Out:
# 7

# %%
np.random.randn()#Random Num which has a Mean of 0 and Std dev of 1
# Out:
# -0.0822567871953219

# %%
numbers  = np.random.randn(2,4)#Ran Numb with an a 2d array 2 rows and 4 columns

# %%
numbers.shape#Print array
# Out:
# (2, 4)

# %%
numbers = numbers.reshape(-1)#Reshape the array to 1 dimensional

# %%
numbers.shape#Print array
# Out:
# (8,)

# %%
numbers= np.array([1,2,2,3,3,3,4,4,4,4])#Array

# %%
plt.hist(numbers,100);#Print hist

# %%
numbers = np.random.randn(100000,)#Rand Num # many times
plt.hist(numbers,100);#Print hist

# %%
numbers = np.random.rand(1000000,)#Rand Num # many times
plt.hist(numbers,100);#Print hist

# %%
np.random.seed(12345)#The same seq of rand number generate each time ran
data = np.random.randn(2, 100)#2 by 100 array of numbers

plt.figure(1, figsize=(9, 9))#Creates a figure object with a size of 9 by 9

plt.subplot(2,2,1)#Pluts 4 subplots in a 2 by 2 grid/#Location of Graph
plt.hist(data[0])#Hist of the first row

plt.subplot(2,2,2)#Location of Graph
plt.scatter(data[0], data[1])#Scatter plot of first row and second row of data array

plt.subplot(2,2,3)#Location of Graph
plt.plot(data[0], data[1],'-')#Line plot"   "

plt.subplot(2,2,4)#Location of Graph
plt.hist2d(data[0], data[1])#2d Hist

plt.show()#Plot

# %% [markdown]
# Normal Dist Data

# %%
x = 10*np.random.randn(10000)#10 times Rand Num

# %%
plt.hist(x);#Plot Hist

# %%
x = np.random.rand(1000)#Rand Num for #

# %%
plt.hist(x);#Plot Hist

# %%
mu = 0  # mean of distribution
sigma = 1  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# %%
n,bins,patches = plt.hist(x,bins=100)

# %%
bins
# Out:
# array([-3.48839929, -3.41454003, -3.34068076, -3.2668215 , -3.19296224,
#        -3.11910298, -3.04524371, -2.97138445, -2.89752519, -2.82366593,
#        -2.74980666, -2.6759474 , -2.60208814, -2.52822887, -2.45436961,
#        -2.38051035, -2.30665109, -2.23279182, -2.15893256, -2.0850733 ,
#        -2.01121404, -1.93735477, -1.86349551, -1.78963625, -1.71577699,
#        -1.64191772, -1.56805846, -1.4941992 , -1.42033994, -1.34648067,
#        -1.27262141, -1.19876215, -1.12490289, -1.05104362, -0.97718436,
#        -0.9033251 , -0.82946583, -0.75560657, -0.68174731, -0.60788805,
#        -0.53402878, -0.46016952, -0.38631026, -0.312451  , -0.23859173,
#        -0.16473247, -0.09087321, -0.01701395,  0.05684532,  0.13070458,
#         0.20456384,  0.2784231 ,  0.35228237,  0.42614163,  0.50000089,
#         0.57386015,  0.64771942,  0.72157868,  0.79543794,  0.86929721,
#         0.94315647,  1.01701573,  1.09087499,  1.16473426,  1.23859352,
# ...

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))#Eq of Array
plt.plot(y)#Plot

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)#Creates Hist set to a # of bins set the density to true it shows the prob density and not the value of each bin
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))#Calc the value of the normal dist of each point
plt.plot(bins,y)#Plot

# %%
x
# Out:
# array([ 0.43140694,  0.92232551, -0.28579044, ...,  0.95077484,
#         0.86182911,  1.35330879])

# %%
def mean(x):#Calc mean of x
    return np.sum(x)/x.shape[0]#Sum/Number of bins - Calc Mean

# %%
def var(x):#Var calculates the variance of the array x
    return mean((x - mean(x))**2)

# %%
def std(x):#Std of X
    return np.sqrt(var(x))

# %%
def median(x):#Set X
    n = len(x)#Calc # of elements in array
    sorted_x = np.sort(x)#Sorts the array
    mid = n // 2#Calc middle index - Results come out as an integer
    if n % 2 == 0:#If array is even then med is calc as average of the two middle elements
        return (sorted_x[mid - 1] + sorted_x[mid]) / 2#^^
    else:
        return sorted_x[mid]#If odd then med is the middle element

# %%
def mode(x):#Set X
    values, counts = np.unique(x, return_counts=True)#Identify the unique value in the array and returns each value
    max_count_index = np.argmax(counts)##Find the index of the max count the array
    return values[max_count_index]#Acces the corresponding unique vlaue

# %%
def range(x):
    return np.max(x) - np.min(x)#Subracts the max by the min value to find the range

# %%
data = np.array([1, 2, 2, 3, 4, 5, 5, 5, 6])

# Testing the functions
mean_value = mean(data)#Mean
var_value = var(data)#Variance
std_value = std(data)#Standard Deviation
median_value = median(data)#Median
mode_value = mode(data)#Mode
range_value = range(data)#Range

mean_value, var_value, std_value, median_value, mode_value, range_value
# Out:
# (3.6666666666666665, 2.6666666666666665, 1.632993161855452, 4, 5, 5)

# %% [markdown]
# # Pi from Random Numbers

# %%
N = 10#Set N

# %%
points = -1 + 2*np.random.random((N,2))#Plot Randome points in 2 dim

# %%
points#Show Points
# Out:
# array([[-0.80196204, -0.26723235],
#        [ 0.07232233,  0.0159817 ],
#        [ 0.79619359,  0.79434842],
#        [-0.1867458 , -0.83607379],
#        [ 0.41250286, -0.05524976],
#        [ 0.70571915, -0.52481856],
#        [ 0.3166776 , -0.91915146],
#        [ 0.11681585, -0.49486802],
#        [-0.52976532, -0.86987235],
#        [-0.56212195,  0.57565   ]])

# %%
plt.plot(points[:,0],points[:,1],'.')#X and Y which is 1 and 2 second column

plt.gca().set_aspect(1)#Current Axes and Sets Aspect Ratio

# %%
inside_circle  = points[:,0]**2 + points[:,1]**2  <=  1#Great then or equal too 1
outside_circle = points[:,0]**2 + points[:,1]**2  > 1#Great then or equal too 1

plt.plot(points[inside_circle,0],points[inside_circle,1],'g.')#X and Y which is 1 and 2 second column and set color green
plt.plot(points[outside_circle,0],points[outside_circle,1],'r.')#X and Y which is 1 and 2 second column set color red


plt.gca().set_aspect(1)#Current Axes and Sets Aspect Ratio

# %%
np.sum(inside_circle),np.sum(outside_circle)#Sum of points Inside and Outside the range
# Out:
# (8, 2)

# %%
total_area = 4#Area

# %%
fraction_inside = np.sum(inside_circle)/N#Sum of points inside of cicrle/the total numbers of points

# %%
fraction_inside*total_area
# Out:
# 3.2

# %%
N = 100000000#Num of Points
points = -1 + 2*np.random.random((N,2))#Plot Rand points in 2 dim
inside_circle  = points[:,0]**2 + points[:,1]**2  <=  1
fraction_inside = np.sum(inside_circle)/N
fraction_inside*4
# Out:
# 3.14159784

# %% [markdown]
# # Complete Code for Estimating π using Monte Carlo Simulation

# %%
# Number of random points to generate
num_points = 10000

# Generating random points
x_points = np.random.uniform(-1, 1, num_points)
y_points = np.random.uniform(-1, 1, num_points)

# Calculating the number of points inside the quarter circle
points_inside = np.sqrt(x_points**2 + y_points**2) <= 1
num_inside = np.sum(points_inside)

# Estimating π
pi_estimate = 4 * num_inside / num_points

# Plotting the points and the quarter circle
plt.figure(figsize=(6, 6))
plt.scatter(x_points[points_inside], y_points[points_inside], color='green', label='Inside')
plt.scatter(x_points[~points_inside], y_points[~points_inside], color='red', label='Outside')
circle = plt.Circle((0, 0), 1, color='blue', fill=False)
plt.gca().add_artist(circle)
plt.title('Estimating π using Monte Carlo Simulation')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.axis('equal')
plt.show()

pi_estimate
# Out:
# 3.1356

# %% [markdown]
# # e from Random Numbers

# %%
X = np.random.random((1000000,10))#Gen rand num with # rows and # COLUNMS

# %%
Y = np.cumsum(X,1)#Calc Cum sum along the second axis(1)

# %%
Z = np.argmax(Y > 1,1) + 1#Contain the index of the first element in each row of the array Y that is greater than 1, plus 1

# %%
np.mean(Z)#Mean
# Out:
# 2.718006

# %%
np.mean(np.argmax(np.cumsum(np.random.random((10000000,10)),1) > 1,1) + 1)#Cal e
# Out:
# 2.7181386

# %%
np.exp(1)
# Out:
# 2.718281828459045
