# %% [markdown]
# <a href="https://colab.research.google.com/github/dlora2024/Prob-Stat/blob/main/Lab_1_Basic_Calculations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python Basics

# %% [markdown]
# ### Calculator

# %%
# Comments with hashtag, python ignores this

# %%
#Addation
30.34321 + 9.12313 - 3.5567
# Out:
# 35.90964

# %%
#Multiplaction
2*2
# Out:
# 4

# %%
#Power
2**8
# Out:
# 256

# %%
#Power
2**123
# Out:
# 10633823966279326983230456482242756608

# %%
#Power
2**12345
# Out:
# ...

# %%
#Dont Know
import sys
sys.set_int_max_str_digits(100000)
2**45678
# Out:
# ...

# %%
#Divsion With Dec.
8/4
# Out:
# 2.0

# %%
#Divsion
8//4
# Out:
# 2

# %%
#Returns Remainder
8%12
# Out:
# 8

# %%
#Returns Remainder
13%12
# Out:
# 1

# %%
#Returns Remainder
22%12
# Out:
# 10

# %%
#Returns Remainder
24%12
# Out:
# 0

# %% [markdown]
# ### Variables

# %%
#Define Varb.
apples = 5

# %%
#Define Varb.
oranges = 8

# %%
#Add of both Varb.
total = apples + oranges

# %%
#Print total
total
# Out:
# 13

# %%
#Multi Varb By 2
apples**2
# Out:
# 25

# %%
#Set cost for Varb
cost_per_apple = 0.25

# %%
#Eq to Calc Cost per apple
total_apple_costs = cost_per_apple * apples

# %%
#Print Calc
total_apple_costs
# Out:
# 1.25
